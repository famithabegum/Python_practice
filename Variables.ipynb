# %%
x = 1
y = 2
print(x+y)
# Out:
# 3

# %%
car_name= "Volvo"
print(type(car_name))
# Out:
# <class 'str'>

# %%
z = 3
print(x+y+z)
# Out:
# 6

# %%
x="sun"
y="flower"
z=x+y
print(z)
# Out:
# sunflower

# %%
pizza=int("500")
coke=50
friedrice=200
print(pizza+coke+friedrice)
# Out:
# 750

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
food=float("120.34") #double quotes data is considered as string always
rent=float("500.67") #declaring data type when we put data between double quotes
total= food+rent     # this is known as "CASTING"
total
# Out:
# 621.01

# %%
import math  #importing math function
x= 25
math.sqrt(x)
# Out:
# 5.0

# %%
math.floor(10.5)    #floor math fn gives the lower value
# Out:
# 10

# %%
math.ceil(10.5)     #ceiling math fn gives the upper value
# Out:
# 11

# %%
first = "Abdul"
last = "Kalam"
name = first +" "+last
name
# Out:
# 'Abdul Kalam'

# %%
status = "passed away"
name = f"{first} {last} was {status}"
name
# Out:
# 'Abdul Kalam was passed away'

# %%
(name[0:5])    #a-0 b-1 d-2 u-3 l-4   ( we have to put one additional index for last)
# Out:
# 'Abdul'

# %%
x = 10
y = 20
#print(i add x and y and ans is x+y ) 
print(f" i add {x} and {y} and ans is {x+y}")
# Out:
#  i add 10 and 20 and ans is 30

# %%
name = "thanjavur"
name = 's'+ name[5:]
print(name)
# Out:
# savur

# %%
container = '''box, pen, pencil, eraser, scissor, paper, pad,clip, pouch, geomatry, scale, colour pencil, sketch, water colour'''
print(container)
# Out:
# box, pen, pencil, eraser, scissor, paper, pad,clip, pouch, geomatry, scale, colour pencil, sketch, water colour

# %%
"eraser" in container
# Out:
# True

# %%
things = " bottle "
things in container
# Out:
# False

# %%
item = "milk, curd, paneer, snacks, mixture, sweet, fruit, veg, non-veg"
print(item.split(","))
# Out:
# ['milk', ' curd', ' paneer', ' snacks', ' mixture', ' sweet', ' fruit', ' veg', ' non-veg']

# %%
"milk" in item
# Out:
# True

# %%
'palkova' in item
# Out:
# False

# %%
container.find("pen")
# Out:
# 5

# %%
container.index("pen")
# Out:
# 5

# %%
data = " Today we are planning to go out . "
data.strip()    #this fn remove the whitespaces in front and back
# Out:
# 'Today we are planning to go out .'

# %%
data.upper()
# Out:
# ' TODAY WE ARE PLANNING TO GO OUT . '

# %%
data.lower()
# Out:
# ' today we are planning to go out . '

# %%
data.index("to")
# Out:
# 23

# %%
data.replace("we","I am")
# Out:
# ' Today I am are planning to go out . '

# %%
data.find("we")
# Out:
# 7

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...
