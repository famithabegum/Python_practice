# %%
Flavour=["Vennila","Strawberry","Chocolate","Butterscotch","Pista"]
Flavour
# Out:
# ['Vennila', 'Strawberry', 'Chocolate', 'Butterscotch', 'Pista']

# %%
"Pista" in Flavour
# Out:
# True

# %%
"Mango" in Flavour
# Out:
# False

# %%
Flavour=["Vennila","Strawberry","Chocolate","Butterscotch","Pista"]
Flavour[-2]
# Out:
# 'Butterscotch'

# %%
Flavour[2:3]
# Out:
# ['Chocolate']

# %% [raw]
# Flavour=["Vennila","Strawberry","Chocolate","Butterscotch","Pista"]
# Flavour

# %%
Num=[56,12,451,56,9,10,789]
Num.sort()
Num
# Out:
# [9, 10, 12, 56, 56, 451, 789]

# %%
Flavour.append("icecream")   # append fn added item in the last
Flavour
# Out:
# ['Vennila',
#  ('grapes', 'orange'),
#  'Chocolate',
#  'Butterscotch',
#  'icecream',
#  'icecream']

# %%
Flavour[1]="grapes","orange"
Flavour
# Out:
# ['Vennila',
#  ('grapes', 'orange'),
#  'Chocolate',
#  'Butterscotch',
#  'Pista',
#  'icecream']

# %%
Flavour.remove("Pista")
Flavour
# Out:
# ['Vennila', ('grapes', 'orange'), 'Chocolate', 'Butterscotch', 'icecream']

# %%
56 in Num
# Out:
# True

# %%
Num.sort(reverse=True)  # reverse fn gives decendung order
Num
# Out:
# [789, 451, 56, 56, 12, 10, 9]

# %%
stationary = ["pen","eraser","Scale","box"]
stationary
# Out:
# ['pen', 'eraser', 'Scale', 'box']

# %%
stationary = ["pen","eraser","Scale","box"]
Flavour = ["Vennila","Strawberry","Chocolate","Butterscotch","Pista"]
join= stationary+Flavour    # it adds two variable into one
join
# Out:
# ['pen',
#  'eraser',
#  'Scale',
#  'box',
#  'Vennila',
#  'Strawberry',
#  'Chocolate',
#  'Butterscotch',
#  'Pista']

# %%
len(join)  # gives the length of tthe lists
# Out:
# 9
