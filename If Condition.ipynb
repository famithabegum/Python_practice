# %%
n = int(input(" Enter a number:"))
if(n%2==0):
    print(f" {n} is an Even number")
else:
    print(f" {n} is an Odd number")
# Out:
#  Enter a number: 33
#  33 is an Odd number

# %%
n = int(input(" Enter a number:"))
message = "Number is even" if n%2==0 else "Number is odd"
print(message)
# Out:
#  Enter a number: 45
# Number is odd

# %%
n = 10
if (n%2==0 or n<5):
    print(True)
else:
    print(False)
# Out:
# True

# %%
veg = ['tomato' ,'potato', 'cabbage', 'carrot', 'onion']
non_veg = ['fish', 'crab', 'prawn', 'chicken', 'mutton']
others = ['rasam', 'curd', 'butter']
choice=input("Choose your choice:")
if(choice in veg):
    print("Your choice is veg")
elif(choice in non_veg):
    print("Your choice is non_veg")
else:
    print("Your choice is not in list")
# Out:
# Choose your choice: beans
# Your choice is not in list
