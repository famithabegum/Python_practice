# %%
Student = {"Name":"a","Age":"12","percent":"90"}
Student["percent"]
# Out:
# '90'

# %%
value=(12,34,5,6)
value[3]
# Out:
# 6

# %%
items = {'student 1':{'name':'abcd','nr':12345,'mark':90},
        'student 2':{'name':'efghju','nr':4567890,'mark':66}}
items['student 1']['name']
# Out:
# 'abcd'

# %%
d={'name':'fdsafg','nr':4567890,'mark':66}
for name,nr in d.items():
    print(name,nr)
# Out:
# name fdsafg
# nr 4567890
# mark 66

# %%
d.keys()
# Out:
# dict_keys(['name', 'nr', 'mark'])

# %%
d.values()
# Out:
# dict_values(['fdsafg', 4567890, 66])

# %%
value=(5,6,77)
value[2]
# Out:
# 77
